# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
import requests

# %%
#path = "C:\Program Files (x86)\chromedriver.exe"
path2 = '/usr/local/bin/chromedriver'
driver = webdriver.Chrome(path2)
driver.get("https://us.trend-calendar.com/trend/2020-01-01.html")

# %%
counter = 365
trend = {}
l = []
while counter != 0:
    counter -= 1
    header = driver.find_elements_by_class_name("entry-title")
    for content in header:
        res = []
        text = content.text
    date = text.split("on ",1)[1]
    contents = driver.find_elements_by_class_name("ranking")
    for content in contents:
        text = content.text
        if text != '' :
            res.append(text)     
    trends = res[0]    
    trend[date] = trends.split("\n")[:5]
    l.append(trends.split("\n")[:5])
    trends = []
    # click submit button
    submit_button = driver.find_elements_by_class_name("yesterdaytomorrow")[1]
    submit_button.click()
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-ece5fac34ac1> in <module>
#       8         res = []
#       9         text = content.text
# ---> 10     date = text.split("on ",1)[1]
#      11     contents = driver.find_elements_by_class_name("ranking")
#      12     for content in contents:
#
# IndexError: list index out of range

# %%
#trend

# %%
trend['1st January, 2020']
# Out:
# ['Winter Classic 2020',
#  'Post Malone',
#  'Paula Abdul',
#  'Premier League',
#  'Lucy Hale']

# %%
df = pd.DataFrame(l, columns = ['1', '2','3', '4', '5'])
df.head(50)
# Out:
#                              1                              2  \
# 0                 #NewYearsDay                Welcome to 2020
# 1                      New Guy              #ThursdayThoughts
# 2                       #wwlll                     #TrumpsWar
# 3                    Meat Loaf                      #ww3memes
# 4          #IfTheWorldHadNoMen                       #BTSxGDA
# 5                 George Lopez                  #ARMYSelcaDay
# 6             #TuesdayThoughts                    Nikki Haley
# 7             #WednesdayWisdom       #IvotedforHillaryClinton
# 8                       Boosie              #SniffyMcAdderall
# 9                #IAmNonbinary                   Life is Good
# 10                       #Deku  #WorstThingToYellOutBeforeSex
# 11               #PowerSeason6                        Tkachuk
# 12                  #OscarNoms                  #ITrustBernie
# 13                Vince Vaughn               #TuesdayThoughts
# 14             Aaron Hernandez               #WednesdayWisdom
# 15   #SeduceSomeoneInFourWords          #AppreciateADragonDay
# 16                      Eminem                #AFallFromGrace
# 17           National Archives                Incredible Hulk
# 18                       Tariq                       #PowerTV
# 19                       Revis                        #MLKDay
# 20                #ILikeBernie               #TuesdayThoughts
# 21            #WednesdayWisdom                        Fairway
# 22           #ThursdayThoughts                #NationalPieDay
# 23                   Joe Rogan                      B.I.T.C.H
# 24     #AmericansWantWitnesses     #IGotKickedOutOfSpaceForce
# 25             #SundayThoughts                    Born Sinner
# 26                #ILeftTheGOP                       #KobeRIP
# 27                    #girldad                      Don Lemon
# 28               #BellLetsTalk                        Coach K
# 29                     #SFFpit               #dershowitzlogic
# 30       #ImpeachmentTrialSham                      Key Glock
# 31                     Rashida                          Tlaib
# 32                  #SuperBowl                      Mini Mike
# 33           #MondayMotivation                         G Eazy
# 34             #WorldCancerDay                          #SOTU
# 35  #NationalWeatherpersonsDay                         #NGWSD
# 36                Global Entry                #impeached4life
# 37                     Vindman                    James Woods
# 38                  Orson Bean                 Chris Matthews
# 39           #NationalPizzaDay                          Tasha
# 40                 #QueenRadio                          Qinni
# 41             #WomenInScience               #TuesdayThoughts
# 42                  Mel Tucker               #WednesdayWisdom
# 43        10 Movies to Know Me                 #GalentinesDay
# 44                        Tink                      Delta CEO
# 45              Tahitian Treat                         K Camp
# 46                 #DAYTONA500             #HowIFoundTheGSpot
# 47                 John Oliver                         #RTXOn
# 48     #LoseAnArgumentIn3Words          #NationalDrinkWineDay
# 49            #WednesdayWisdom                        Assange
#
#                                  3                          4  \
# 0                             Pope                  #RoseBowl
# 1               #worldintrovertday                       Opie
# 2                           #WWIII               Rose McGowan
# 3                          #njwk14             Tucker Carlson
# 4                   Happy Founders                   #PowerTV
# 5           #RuinAMovieWithOneWord                     Bolton
# 6                       #7isComing   #WithMyNextPaycheckIWill
# 7                    #iHeartAwards             #IranVSAmerica
# 8   #LawEnforcementAppreciationDay          #ThursdayThoughts
# 9                   #FridayFeeling                Sum 2 Prove
# 10        #justinbieberisoverparty     #WitnessesAndDocuments
# 11            #IDidntKnowMyKinkWas                    Kassian
# 12                            Chen                    Jongdae
# 13                   #PortfolioDay              #RefundWarren
# 14                    #NeverWarren                #CNNisTrash
# 15                          Byleth                     Altuve
# 16                       Ken Starr             #FridayFeeling
# 17               #WinnieThePoohDay               Aaron Carter
# 18                 #SundayThoughts         #DisgustMeIn4Words
# 19                 #IEndorseBernie             #VirginiaRally
# 20                     #GOPCoverup                      Jeter
# 21                      Mr. Peanut                Terry Jones
# 22                  #DoomsdayClock              Monster House
# 23           #dollypartonchallenge  #TheSexiestThingYouCanSay
# 24                      Bangladesh            #PompeoMeltdown
# 25                  #WhiteMaleRage                Paula White
# 26                      #iHeartBTS                     Bolton
# 27                #TuesdayThoughts         #AddAWordRuinABook
# 28                #WednesdayWisdom              Chris Doleman
# 29        #WorstWayToEndAnArgument              #MinajInMiami
# 30                  #MissAmericana                      Wayne
# 31             #HappyBirthdayHarry         #BlackHistoryMonth
# 32             #7YearsWithJungkook              #GroundhogDay
# 33               #HalftimeShow2020              #IowaCaucuses
# 34                #TuesdayThoughts                     Shadow
# 35                #WednesdayWisdom                #ImWithFred
# 36                    #BernieWonIA    #MittRomneyAmericanHero
# 37                 Jay Electronica               #YikesOutNow
# 38                        #XFL2020                #OrangeFace
# 39                         #Oscars             #SexSoLoudThat
# 40                      Luke Perry                    Equifax
# 41                            Zaya         #BloombergIsRacist
# 42                     Ashley Judd             #ToAlltheBoys2
# 43                      John Kelly                   Prager U
# 44                  #ValentinesDay                     McCabe
# 45                   Sam Donaldson           #StillVotingYang
# 46                       Lis Smith            #SundayThoughts
# 47               #MondayMotivation             #PresidentsDay
# 48                #TuesdayThoughts                 Boy Scouts
# 49                George Zimmerman               The Exorcist
#
#                                 5
# 0                     #CitrusBowl
# 1                        Anna Mae
# 2                       Soleimani
# 3               #SaturdayThoughts
# 4                   #GoldenGlobes
# 5                    #TheBachelor
# 6                   Meghan McCain
# 7                Jillian Michaels
# 8                  Happy Founders
# 9                     #RareOutNow
# 10               #SaturdayMorning
# 11                #kissagingerday
# 12                         Astros
# 13                     #DemDebate
# 14                   Drew Pearson
# 15                        McSally
# 16                       Kamikaze
# 17  #WorstThingsToYellOutAfterSex
# 18    #DumbThingsIDidInHighSchool
# 19                      Happy MLK
# 20            #PastimesFromThe90s
# 21               #AdamSchiffROCKS
# 22              Church of England
# 23         #NationalComplimentDay
# 24                #CoronaOutbreak
# 25                           Kobe
# 26               Letter to Nipsey
# 27                   Palestinians
# 28               #WeWantWitnesses
# 29                   #YangWillWin
# 30                 #FridayFeeling
# 31                    #BooHillary
# 32                 #PalindromeDay
# 33                #TrumpIsAnIdiot
# 34                    #MayorCheat
# 35                  #LOONA_SOWHAT
# 36            #ThursdayMotivation
# 37                    Cherry Coke
# 38                       Zoey 101
# 39                       #PowerTV
# 40                   #TrumpBudget
# 41                 Dixville Notch
# 42                         Ohio 2
# 43         #WeSupportYouHorikoshi
# 44                     Artist 2.0
# 45                    Ryan Garcia
# 46                 Tony Fernandez
# 47               #PresidentWarren
# 48                Kaitlin Bennett
# 49                    After Hours

# %%
#l

# %%
df.to_csv('trend_list.csv')
